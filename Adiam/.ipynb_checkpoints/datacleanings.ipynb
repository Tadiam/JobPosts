# %%
import pandas as pd
import matplotlib as plt 
import sklearn as sk
import glob
import os

# %%
path = '/Users/adiamtesfaselassie/Documents/Spring2023/ANLY521/JobPosts/Adiam/data/'

jobs = glob.glob(path + "/*.csv")
df_list = (pd.read_csv(file) for file in jobs)
jobs_df = pd.concat(df_list)
jobs_df

#df_jobs = pd.concat([pd.read_csv(f).set_index('A') for f in glob.glob('/Users/adiamtesfaselassie/Documents/Spring2023/ANLY521/JobPosts/Adiam/data')])
# Out:
#                                         Position Name                     Job  \
# 0                        Director of Women's Services  Healthcare Management
# 1         Health Services Director - Registered Nurse  Healthcare Management
# 2                               Program Coordinator I  Healthcare Management
# 3                                 Director of Surgery  Healthcare Management
# 4       Operations Manager, Provider Success (Remote)  Healthcare Management
# ..                                                ...                     ...
# 81                    eDiscovery Analytics Consultant                     NaN
# 82          Junior Data Science Analyst/Engineer (YT)                     NaN
# 83                                     Data Scientist                     NaN
# 84  Consultant, Data & Analytics l Forensic and Li...                     NaN
# 85   Metadata Librarian for Science & Geospatial Data                     NaN
#
#                         Salary      Job Type     Shift & Schedule  \
# 0                          NaN     Full-time                  NaN
# 1                          NaN     Full-time     Monday to Friday
# 2      $17.83 - $30.33 an hour     Full-time                  NaN
# 3                          NaN     Full-time  Monday to Friday +1
# 4                          NaN     Full-time                  NaN
# ..                         ...           ...                  ...
# 81                         NaN     Full-time                  NaN
# 82                         NaN      Contract                  NaN
# 83  $118,300 - $245,700 a year     Full-time                  NaN
# 84                         NaN           NaN                  NaN
# 85    $77,500 - $97,500 a year  Tenure track                  NaN
#
#                    Company                                     Location  \
# 0   Bolivar Medical Center                          Cleveland, MS 38732
# 1      Prestige Care, Inc.             Pendleton, OR 97801+10 locations
# 2         Coordinated Care  Hybrid remote in Washington, DC+4 locations
# 3        Kindred Hospitals                   Rancho Cucamonga, CA 91730
# 4       Path Mental Health                    Remote in Los Angeles, CA
# ..                     ...                                          ...
# 81                Deloitte                  Washington, DC+11 locations
# 82              Blackspoke                              Springfield, VA
# 83                  Leidos                 McLean, VA 22102+2 locations
# 84    FTI Consulting, Inc.     Washington, DC 20004 (Penn Quarter area)
# 85     New York University                               Washington, DC
#
#     Rating                                                URL  \
# 0      3.8  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1      2.7  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2      3.2  https://www.indeed.com/rc/clk?jk=7a151ecfa759e...
# 3      3.3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4      4.7  https://www.indeed.com/rc/clk?jk=5824c54186b26...
# ..     ...                                                ...
# 81     3.9  https://www.indeed.com/rc/clk?jk=ef16b2b784bd1...
# 82     NaN  https://www.indeed.com/rc/clk?jk=68ddc3a8085a5...
# 83     3.7  https://www.indeed.com/rc/clk?jk=640dafb801a6f...
# 84     3.6  https://www.indeed.com/rc/clk?jk=b81425bdf5a22...
# 85     4.2  https://www.indeed.com/rc/clk?jk=f3201aebefab8...
#
#                   Id                  Posted At                Scraped At  \
# 0   7d46e088272f423d  EmployerActive 3 days ago  2023-04-23T17:46:51.335Z
# 1   75134fbb214e21e8  EmployerActive 2 days ago  2023-04-23T17:46:51.335Z
# 2   7a151ecfa759eb7a  PostedPosted 30+ days ago  2023-04-23T17:46:51.336Z
# 3   ecab535cd6ff5437  EmployerActive 3 days ago  2023-04-23T17:46:51.336Z
# 4   5824c54186b26f1d     PostedPosted 1 day ago  2023-04-23T17:46:51.336Z
# ..               ...                        ...                       ...
# 81  ef16b2b784bd1e0d   PostedPosted 16 days ago  2023-04-16T02:51:56.392Z
# 82  68ddc3a8085a55d0   PostedPosted 19 days ago  2023-04-16T02:51:56.392Z
# 83  640dafb801a6f6f9    PostedPosted 3 days ago  2023-04-16T02:51:56.393Z
# 84  b81425bdf5a22815    PostedPosted 9 days ago  2023-04-16T02:51:56.393Z
# 85  f3201aebefab857a   PostedPosted 24 days ago  2023-04-16T02:51:56.393Z
#
#                                     Short Description  \
# 0    \n Utilizes appropriate pain management techn...
# 1    \n Experience in geriatric nursing, medicatio...
# 2    \n Screen members by priority for case manage...
# 3   Kindred Hospital Rancho* is a 55 bed long-term...
# 4    \n Experience with high-growth startups, heal...
# ..                                                ...
# 81   \n In this role, you will specialize in and p...
# 82   \n Although GEOINT is the most critical data ...
# 83   \n Experience working with data manipulation,...
# 84   \n Knowledge of data governance and data priv...
# 85   \n Experience with data science software and ...
#
#                               External Apply Link           Job
# 0   www.indeed.com/applystart?jk=7d46e088272f423d            NaN
# 1   www.indeed.com/applystart?jk=75134fbb214e21e8            NaN
# 2   www.indeed.com/applystart?jk=7a151ecfa759eb7a            NaN
# 3   www.indeed.com/applystart?jk=ecab535cd6ff5437            NaN
# 4   www.indeed.com/applystart?jk=5824c54186b26f1d            NaN
# ..                                            ...            ...
# 81  www.indeed.com/applystart?jk=ef16b2b784bd1e0d  Data Science
# 82  www.indeed.com/applystart?jk=68ddc3a8085a55d0  Data Science
# 83  www.indeed.com/applystart?jk=640dafb801a6f6f9  Data Science
# 84  www.indeed.com/applystart?jk=b81425bdf5a22815  Data Science
# 85  www.indeed.com/applystart?jk=f3201aebefab857a  Data Science
#
# [386 rows x 15 columns]

# %%
discription_df = pd.DataFrame(zip(jobs_df['Short Description'], jobs_df['Job']), columns=['Discription', 'Job'])
discription_df.Job.unique()
discription_df
# Out:
#                                            Discription                     Job
# 0     \n Utilizes appropriate pain management techn...  Healthcare Management
# 1     \n Experience in geriatric nursing, medicatio...  Healthcare Management
# 2     \n Screen members by priority for case manage...  Healthcare Management
# 3    Kindred Hospital Rancho* is a 55 bed long-term...  Healthcare Management
# 4     \n Experience with high-growth startups, heal...  Healthcare Management
# ..                                                 ...                     ...
# 381   \n In this role, you will specialize in and p...                     NaN
# 382   \n Although GEOINT is the most critical data ...                     NaN
# 383   \n Experience working with data manipulation,...                     NaN
# 384   \n Knowledge of data governance and data priv...                     NaN
# 385   \n Experience with data science software and ...                     NaN
#
# [386 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
#from nltk.tokenize import TreebankWordTokenizer
#from nltk.stem import PorterStemmer
import pandas as pd
import re
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# %%
def tokenize_stem(series):
    
    tokenizer =TreebankWordTokenizer() 
    stemmer = PorterStemmer()
    series = series.apply(lambda x: tokenizer.tokenize(x))
    series = series.apply(lambda x: [stemmer.stem(w) for w in x])
    series = series.apply(lambda x: ' '.join(x))
    return series

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for i, topic in enumerate(model.components_):
        if not topic_names or not topic_names[i]:
            print("\nTopic ", i)
        else:
            print("\nTopic: '",topic_names[i],"'")
        print(", ".join([feature_names[k]
                        for k in topic.argsort()[:-no_top_words - 1:-1]]))
    return [topic for topic in model.components_]
    return model.components_

# %%
def return_topics(series, num_topics, no_top_words, model, vectorizer):
    #turn job into series
    #df = jobs_df[jobs_df['Job']==job]
    
    
    #clean series
    
    series = tokenize_stem(series)
    #transform series into corpus
    ex_label = [e[:30]+"..." for e in series]
    #set vectorizer ngrams = (2,2)
    vec = vectorizer(stop_words = 'english')
    
    doc_word = vec.fit_transform(series)
    def_model = model(num_topics)
    doc_topic = def_model.fit_transform(doc_word)
    
    display_topics(def_model, vec.get_feature_names(), no_top_words)
    return def_model.components_, doc_topic#, topics

# %%
lsa = TruncatedSVD(2)
array,doc = return_topics(discription_df['Description'],20, 10, NMF, TfidfVectorizer)
doc.shape

# look at topics and see what makes sense

# recommend roles that are best for you based on supervised learnings

# these are the jobs descriptions that are best for you based on your resume

# these are the best words for your resume based on which job you want to go into

Topic_DF = pd.DataFrame(doc)
Topic_DF.columns = ['Topic ' + str(i+1) for i in range(len(Topic_DF.columns)) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 lsa = TruncatedSVD(2)
#       2 array,doc = return_topics(discription_df['Description'],20, 10, NMF, TfidfVectorizer)
#       3 doc.shape
#
# NameError: name 'TruncatedSVD' is not defined
